# %% [raw]
# ---
# Title: AI Gateway
# Author: [Author Name] <[Author Email]>
# Description: "Test MlFlow AI Gateway"
# ---

# %%
import os
os.chdir('..')

import warnings
warnings.filterwarnings('ignore')

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# python-dotenv could not parse statement starting at line 16
# True

# %%
from src.utils.mlflow import load_model

# %%
llama = load_model("llama3.1-8b")
gpt = load_model("gpt-5.2")

# %%
llama.invoke("What is the capital of Norway ?")
# Out:
# AIMessage(content='### Solution\nOslo.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 20, 'total_tokens': 27, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'ollama/llama3.1:8b', 'system_fingerprint': None, 'id': 'chatcmpl-652abeda-ae5e-4ab0-9c3d-dc958df1359a', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d05a3-a04d-7512-9e99-c21b50d9a1cc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 20, 'output_tokens': 7, 'total_tokens': 27, 'input_token_details': {}, 'output_token_details': {}})

# %%
gpt.invoke("What is the capital of Norway ?")
# Out:
# AIMessage(content='The capital of Norway is **Oslo**.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 13, 'total_tokens': 27, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.2-2025-12-11', 'system_fingerprint': None, 'id': 'chatcmpl-DL502lDivhxbFnFHbebZ9pztDR1QZ', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d05a9-5972-7912-be75-bd4951cb8f80-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 14, 'total_tokens': 27, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}})
